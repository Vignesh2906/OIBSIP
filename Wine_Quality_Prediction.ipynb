# %% [markdown]
# ### **Wine Quality Prediction**
#
# Name: Vignesh.M
#
# Domain: Data Analytics
#
# Oasis Infobyte Virtual Internship Program

# %% [markdown]
# **Loading the Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/WineQT.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.nunique()
# Out:
# fixed acidity             91
# volatile acidity         135
# citric acid               77
# residual sugar            80
# chlorides                131
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# Id                      1143
# dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %% [markdown]
# **Data Visualisation**

# %% [markdown]
# **Bar Plot**

# %%
# Bar Plot

plt.figure(figsize=(10,10))
sns.barplot(x='quality',y='alcohol',data=df, palette='viridis')
plt.title('Quality vs Alcohol')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()


plt.figure(figsize=(10,10))
sns.barplot(x='quality',y='volatile acidity',data=df, palette='viridis')
plt.title('Quality vs Volatile Acidity')
plt.xlabel('Quality')
plt.ylabel('Volatile Acidity')
plt.show()

plt.figure(figsize=(10,10))
sns.barplot(x='quality',y='citric acid',data=df, palette='viridis')
plt.title('Quality vs Citric Acid')
plt.xlabel('Quality')
plt.ylabel('Citric Acid')
plt.show()

# %% [markdown]
# **Correlation Heatmap**

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Distribution Plot**

# %%
# Distribution plot

plt.figure(figsize=(15,10))

columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide']
colors = ['skyblue','coral','gold','lightgreen','salmon','plum']

for i, variable in enumerate(columns):
    plt.subplot(3, 2, i+1)
    sns.histplot(df[variable], kde=True, color=colors[i])
    plt.title(f'Distribution of {variable}')
    plt.xlabel(variable)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


plt.figure(figsize=(15,10))

columns = ['total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']
colors = ['dodgerblue', 'limegreen', 'gold', 'crimson', 'slategray', 'lightgray']

for i, variable in enumerate(columns):
    plt.subplot(3, 2, i+1)
    sns.histplot(df[variable], kde=True, color=colors[i])
    plt.title(f'Distribution of {variable}')
    plt.xlabel(variable)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Countplot**

# %%
# Count Plot

sns.countplot(x='quality', data=df, palette='rocket')
plt.title('Count of Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Replot**

# %%
# Relplot

sns.relplot(x='fixed acidity', y='volatile acidity', data=df, hue='quality', palette='Set1')
sns.relplot(x='alcohol', y='pH', data=df, hue='quality', palette='Set1')
sns.relplot(x='sulphates', y='alcohol', data=df, hue='quality', palette='Set1')
sns.relplot(x='volatile acidity', y='citric acid', data=df, hue='quality', palette='Set1')

# %% [markdown]
# **KDE Plot**

# %%
# KDE Plot

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='alcohol', hue='quality', fill=True, common_norm=False, palette="Set1", alpha=.5, linewidth=0)
plt.title('Alcohol Distribution by Quality (KDE Plot)')
plt.xlabel('Alcohol')
plt.ylabel('Density')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='pH', hue='quality', fill=True, common_norm=False, palette="Set1", alpha=.5, linewidth=0)
plt.title('pH Distribution by Quality (KDE Plot)')
plt.xlabel('pH')
plt.ylabel('Density')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='density', hue='quality', fill=True, common_norm=False, palette="Set1", alpha=.5, linewidth=0)
plt.title('Density Distribution by Quality (KDE Plot)')
plt.xlabel('Density')
plt.ylabel('Density')
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='residual sugar', hue='quality', fill=True, common_norm=False, palette="Set1", alpha=.5, linewidth=0)
plt.title('Residual Sugar Distribution by Quality (KDE Plot)')
plt.xlabel('Residual Sugar')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# **Data Preprocessing**

# %%
# Separate the data and label

X = df.drop('quality', axis=1)
print(X)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# **Label Binarisation**

# %%
Y = df['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1138    0
# 1139    0
# 1140    0
# 1141    0
# 1142    0
# Name: quality, Length: 1143, dtype: int64

# %% [markdown]
# **Train and Test Split**

# %%
#Train and Test Split

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test, = train_test_split(X, Y, test_size=0.2, random_state=2)
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (1143,) (914,) (229,)

# %% [markdown]
# **Model Training**

# %% [markdown]
# **Random Forest Classifier**

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# **Model Evaluation**

# %% [markdown]
# **Accuracy Score**

# %%
#Accuracy on Test data

from sklearn.metrics import accuracy_score

X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy:', test_data_accuracy)
# Out:
# Accuracy: 0.9082969432314411

# %% [markdown]
# **Building a Predictive System**

# %%
# Building a predictive system

input_data = (7.3, 0.65, 0.0, 1.2, 0.065, 15.0, 21.0, 0.9946, 3.39, 0.47, 10.0, 1.0)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [0]
# Bad Quality Wine

# %% [markdown]
# **END**
